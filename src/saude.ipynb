# %%
from sqlalchemy import select, or_, func
from sqlalchemy.orm import Session

from models import Patent, InternationalClassification
from settings import engine


# Prefixos IPC da área da saúde
HEALTH_IPC_PREFIXES = [

    "A61B",
    "A61C",
    "A61D",
    "A61F",
    "A61K",
    "A61M",
    "A61N",
    "A61P",

    #"C12N",
    #"C12Q",
    #"G01N"
]


def main():
    with Session(engine) as session:

        stmt = (
            select(Patent)
            .join(Patent.international_classifications)
            .where(
                or_(
                    *[
                        InternationalClassification.code.like(f"{prefix}%")
                        for prefix in HEALTH_IPC_PREFIXES
                    ]
                )
            )
            .distinct()
        )

        count_stmt = (
            select(func.count(func.distinct(Patent.id)))
            .join(Patent.international_classifications)
            .where(
                or_(
                    *[
                        InternationalClassification.code.like(f"{prefix}%")
                        for prefix in HEALTH_IPC_PREFIXES
                    ]
                )
            )
        )

        total = session.execute(count_stmt).scalar_one()
        print(f"\nTotal de patentes da área da saúde: {total}\n")

        sample_patents = session.execute(stmt.limit(200)).scalars().all()

        print("Alguns exemplos:")
        for patent in sample_patents:
            print(f"- {patent.name}")


if __name__ == "__main__":
    main()
# Out:
# Total de patentes da área da saúde: 59346
#
# Alguns exemplos:
# - INSTRUMENTO CIRÚRGICO
# - DISPOSITIVO AUTOLIMPANTE PARA LENTE DE ENDOSCÓPIO
# - SISTEMA E MÉTODO APRIMORADOS PARA AJUSTE DA RIGIDEZ DO CATETER
# - INSTRUMENTO MÉDICO
# - DISPOSITIVO UNIVERSAL DE VIDEOSCOPIA PARA INSPEÇÃO E REALIZAÇÃO DE PROCEDIMENTOS MÉDICOS VETERINÁRIOS VIA CELULAR
# - TUBO ENDOTRAQUEAL COM DISPOSITIVO DE CAPTURA DE IMAGEM
# - LARINGOSCÓPIO MECÂNICO COM MECANISMO AUTOMÁTICO OU MANUAL DE ALAVANCAS PARA FACILITAÇÃO DA INTUBAÇÃO TRAQUEAL
# - DISPOSITIVO ODONTOLÓGICO ELETRÔNICO E SISTEMA EMBARCADO EM DISPOSITIVO ODONTOLÓGICO ELETRÔNICO
# - ACESSÓRIO ENDOSCÓPICO COM SISTEMA DE UTILIZAÇÃO COM E SEM FILTRO PARA VISUALIZAÇÃO DE CORANTES FLUORESCENTES
# - APARATO PARA TREINAMENTO DE PROCEDIMENTOS CIRÚRGICOS, SISTEMA PARA TREINAMENTO DE PROCEDIMENTOS DE LAPAROSCOPIA E PROCESSO DE MONTAGEM DE APARATO
# - DISPOSITIVO OPERATÓRIO LEVE
# - SUPORTE ORAL PARA MICRO ESCANEAMENTO E ANÁLISE DA MICROCIRCULAÇÃO SUBLINGUAL
# - CATETER COM IRRIGADOR E/OU ASPIRADOR E COM ANALISADOR DE COÁGULO CEREBRAL DE FIBRA ÓPTICA
# - COMPENSAÇÃO DE ARTEFATOS DURANTE O RASTREAMENTO COM UMA SONDA INTRACORPÓREA
# - CATETER DE BALÃO COM ELETRODOS DE DIAGNÓSTICO, ELETRODOS DE DETECÇÃO DE CAMPO DISTANTE E FIO-GUIA
# - DISPOSITIVO PARA DISTENSÃO DE CANAL, PROCESSO DE PRODUÇÃO DE DISPOSITIVO E KIT
# - ENDOSCÓPIO COM ACESSÓRIO DE INSPEÇÃO E ACESSÓRIO DE INSPEÇÃO PARA O MESMO
# - ESPÉCULO AURICULAR E NASAL PARA CAPTAÇÃO DE IMAGEM
# - DISPOSITIVO PARA A COAGULAÇÃO DE TECIDOS
# - DISPOSITIVO PARA TRACIONAMENTO DE FIBRA ÓTICA EM TÉCNICA DE ABLAÇÃO TÉRMICA
# - DISPOSITIVO DE AFIXAÇÃO DE TUBOS MÉDICOS
# - SOPRADOR DE AR COMPRIMIDO PARA PONTEIRA DE SCANNER INTRAORAL ODONTOLÓGICO
# - VÁLVULA LABIAL PARA ISOLAMENTO DA CAVIDADE ORAL, VENTILAÇÃO E PASSAGEM DE INSTRUMENTOS E TUBOS EM GERAL
# - CÂMERA ENDOSCÓPICA COM ACESSÓRIOS PARA VIDEOLARINGOSCOPIA COM TAMANHO DE LÂMINA AJUSTÁVEL
# - DESENVOLVIMENTO DE VÍDEOLARINGOSCÓPIO DE ALTA CAPACIDADE E BAIXO CUSTO COM TECNOLOGIA NACIONAL
# - CONFIGURAÇÃO DE DISPOSITIVO PARA SONDAGEM ENDOTRAQUEAL UTILIZANDO DISPOSITIVOS ELETRÔNICOS DE IMAGEM
# - ARRANJO DE CÂMERA ENDOSCÓPICA E MÉTODO PARA CORREÇÃO DE ERRO DE ALINHAMENTO DE CÂMERA
# - DISPOSITIVO DE FOTOTERAPIA PARA CANAL VAGINAL E COLO UTERINO
# - MONITOR REMOTO PARA ENDOSCÓPIOS FLEXÍVEIS
# - DISPOSITIVO MÉDICO ENDOSCÓPICO, EM PARTICULAR PARA COLONOSCOPIA
# - ENDOSCÓPIO E PROCEDIMENTO PARA A OPERAÇÃO
# - DISPOSITIVO E MÉTODO DE IMAGIOLOGIA MÉDICA
# - DISPOSITIVO E MÉTODO PARA FORMAÇÃO DE IMAGENS MÉDICAS
# - ENDOSCÓPIO COM ORIENTAÇÃO DE CÂMERA NÃO AXIAL
# - ACESSÓRIO PARA ENCERRAR PARCIALMENTE UMA HASTE DE UM ENDOSCÓPIO E ENDOSCÓPIO
# - DISPOSITIVO DE MONITORAMENTO INTRAVAGINAL E REDE
# - DISPOSITIVO CIRÚRGICO E DISPOSITIVO CIRÚRGICO LAPAROSCÓPICO
# - SISTEMA CIRÚRGICO DE CÂNULA CURVA
# - INTRODUTOR PARA INTRODUZIR UM GRAMPEADOR CIRÚRGICO CIRCULAR
# - INTRODUTOR
# - COBERTURA PARA UMA HASTE DE COLONOSCÓPIO E A REFERIDA HASTE DE COLONOSCÓPIO
# - APARELHO INTEGRAL PARA TESTAR E/OU LIMPAR UM DISPOSITIVO MÉDICO CONTENDO CANAIS e MÉTODO PARA TESTAR UM DISPOSITIVO MÉDICO
# - SISTEMA DE APLICAÇÃO DE ENERGIA COM TUBO-GUIA DE ABLAÇÃO
# - SISTEMA DE HISTEROSCOPIA
# - APARELHO PARA ANÁLISE ÓPTICA DE UM TECIDO ASSOCIADO, MÉTODO PARA ANÁLISE ÓPTICA DE UM TECIDO ASSOCIADO E PRODUTO DE PROGRAMA DE COMPUTADOR
# - MÉTODO E SISTEMA PARA REALÇAR AS ESTRUTURAS DE ALTO RISCO EM UM PROCESSAMENTO VIRTUAL PARA USO DURANTE UM PROCEDIMENTO DE INTERVENÇÃO EM UM LÚMEN CORPORAL
# - SISTEMA DE VÁCUO PARA A TERAPIA DE VÁCUO ENDOSCÓPICA E ARRANJO DE ENDOSCOPIA
# - SONDA CIRÚRGICA ÓPTICA ARTICULADA
# - Sistema de trocarte ótico
# - MÉTODO PARA COLOCAR UMA PORTA PARA UMA FERRAMENTA CIRÚRGICA EM RELAÇÃO A DADOS ANATÔMICOS EM TEMPO REAL, DISPOSITIVO PARA LOCALIZAR UMA PORTA PARA UMA FERRAMENTA CIRÚRGICA EM RELAÇÃO A DADOS ANATÔMICOS EM TEMPO REAL DE UM ENDOSCÓPIO, SISTEMA PARA LOCALIZAR UMA PORTA PARA UMA FERRAMENTA CIRÚRGICA EM RELAÇÃO A UM ENDOSCÓPIO, E PRODUTO DE PROGRAMA DE COMPUTADOR
# - CÁPSULA GASTROINTESTINAL
# - APARELHO PARA OPERAÇÃO EM TECIDO
# - SISTEMA PARA REGISTRAR UM SISTEMA DE COORDENADAS DE UM SISTEMA DE DETECÇÃO DE FORMATO, MÉTODO PARA REGISTRAR UM SISTEMA DE COORDENADAS DE UM SISTEMA DE DETECÇÃO DE FORMATO
# - GUIA TUBULAR FLEXÍVEL E EXTENSÍVEL E PROCESSO PARA A PRODUÇÃO DE UMA GUIA
# - MÉTODO PARA ARMAZENAR EQUIPAMENTO MÉDICO, KIT PARA O ARMAZENAMENTO DE EQUIPAMENTO MÉDICO, E, CONJUNTO
# - ENDOSCÓPIO QUE TEM UMA MONTAGEM DE MANÍPULO PROXIMAL E UM EIXO DE INSERÇÃO DISTAL
# - DISPOSITIVO COMPREENDENDO UMA LUVA ENDOSCÓPICA
# - SISTEMA MANIPULADOR ROBÓTICO
# - SISTEMA DE IMAGEAMENTO CIRÚRGICO
# - Dispositivo para o transporte e armazenamento temporário de um instrumento médico
# - CABO PARA TRANSMISSÃO DE ENERGIA DE RADIOFREQUÊNCIA E/OU DE FREQUÊNCIA DE MICRO-ONDAS PARA UM INSTRUMENTO ELETROCIRÚRGICO
# - ENDOSCÓPIO FLEXÍVEL
# - UNIDADE DE CONTROLE PARA UM ENDOSCÓPIO FLEXÍVEL.
# - OTOSCÓPIO MÓVEL USÁVEL PARA OS DOIS OUVIDOS
# - SISTEMA, MÉTODO PARA FILTRAR LUZ POLARIZADA E KIT PARA USAR COM UM SISTEMA QUE TEM LENTE BIRREFRINGENTE
# - SISTEMA E MÉTODOS DE ACESSO EPICARDIAL
# - SONDA PEDICULAR ENDOSCÓPICA ILUMINADA COM MONITORAMENTO DINÂMICO EM TEMPO REAL PARA A PROXIMIDADE COM OS NERVOS
# - MECANISMO DE ROTAÇÃO DE INSTRUMENTOS PARA UM DISPOSITIVO DE EXPLORAÇÃO CIRÚRGICA
# - COMPARAÇÃO DE UM ARRANJO DENTÁRIO ATUAL COM UMA SÉRIE DE ARRANJOS DENTÁRIOS PRÉ-DEFINIDOS
# - SISTEMAS E MÉTODOS PARA APLICAÇÃO DE ENERGIA
# - DISPOSITIVO DE CANAL PARA UM CONJUNTO DE ESCOPO
# - SISTEMA DE SUTURA ENDOSCÓPICO QUE TEM CANAL DE INSTRUMENTOS EXTERNO
# - APARELHO, E MÉTODO PARA REALIZAR UM PROCEDIMENTO EM UM LÚMEN DE CORPO E/OU CAVIDADE DE CORPO
# - ESTRUTURA DE TRANSPORTE DE ENERGIA ELETROCIRÚRGICA E DISPOSITIVO ELETROCIRÚRGICO INCORPORANDO A MESMA
# - UNIDADE DE CUIDADO DENTÁRIO.
# - DISPOSITIVO DE PROPULSÃO E MÉTODO PARA AVANÇAR UM INSTRUMENTO AO LONGO DE UMA PASSAGEM, UNIDADE DE TUBO DE PROPULSÃO E CONSOLE DE ACIONAMENTO
# - APARELHO E MÉTODOS PARA IDENTIFICAÇÃO DE TECIDO ENDOMETRIAL
# - SISTEMA DE JANELA PARA SCANNER INTRAORAL
# - ARRANJO DE FAN-OUT PERMANENTE
# - DISPOSITIVO DE INVAGINAÇÃO
# - APARELHO PARA VISUALIZAÇÃO APRIMORADA PARA PROCEDIMENTOS ENDOSCÓPICOS
# - DISPOSITIVO DE FORMAÇÃO DE IMAGEM PARA USO EM INTERVENÇÕES MÉDICAS.
# - APARELHO PARA AUXILIAR NO DIAGNÓSTICO POR IMAGEM, MÉTODO PARA A COLETA DE DADOS, MÉTODO PARA AUXILIAR NO DIAGNÓSTICO POR IMAGEM E PROGRAMA PARA AUXILIAR NO DIAGNÓSTICO POR IMAGEM
# - ESPÉCULO VAGINAL
# - SOBRETUBO DE ENDOSCÓPIO E ENDOSCÓPIO
# - TELA DE ALINHAMENTO DE CARTUCHO DE GRAMPOS EM RELAÇÃO A LINHA DE GRAMPOS LINEAR PRECEDENTE
# - IMAGEAMENTO HIPERESPECTRAL EM UM AMBIENTE COM DEFICIÊNCIA DE LUZ
# - RECONHECIMENTO ESPACIAL DE CONTROLADOR CIRÚRGICO CENTRAL PARA DETERMINAR DISPOSITIVOS EM SALA DE CIRURGIA
# - CONTROLADOR CENTRAL DE COMUNICAÇÃO E DISPOSITIVO DE ARMAZENAMENTO PARA PARÂMETROS DE ARMAZENAMENTO E ESTADO E DE UM DISPOSITIVO CIRÚRGICO A SEREM COMPARTILHADOS COM SISTEMAS DE ANÁLISE BASEADOS EM NUVEM
# - IMAGEAMENTO DE MATRIZ DE CMOS DUPLA
# - INSTRUMENTO CIRÚRGICO INTERATIVO
# - FERRAMENTAS E SISTEMAS DE LIBERAÇÃO DE DISPOSITIVO
# - APARELHO DE LASER MÉDICO, CONTROLADOR DE ENDOSCÓPIO E SISTEMA MÉDICO
# - COMPOSIÇÕES E MÉTODOS PARA DIRECIONAR DISPOSITIVOS ENDOSCÓPICOS
# - SISTEMAS E MÉTODOS PARA PROCESSAR VÍDEO EM TEMPO REAL DE UM DISPOSITIVO DE IMAGEM MÉDICA E DETECTAR OBJETOS NO VÍDEO
# - DISPOSITIVO DE IMAGIOLOGIA INTRAORAL
# - PROCESSO DE MEDIÇÃO ÓTICA E DISPOSITIVO DE MEDIÇÃO ÓTICA
# - DISPOSITIVO E KIT DE REMOÇÃO DE OSSO, BROCA PARA OSSO DE UM DISPOSITIVO DE REMOÇÃO DE OSSO, E, MÉTODOS PARA PERFURAR OSSO, PARA FABRICAR UM DISPOSITIVO DE REMOÇÃO DE OSSO, PARA MONTAGEM DE UM DISPOSITIVO DE REMOÇÃO DE OSSO E PARA TRATAMENTO USANDO UM DISPOSITIVO DE REMOÇÃO DE OSSO
# - SONDA ENDOSCÓPICA ILUMINADA TRANSLÚCIDA
# - CORREÇÃO DE IMAGEM DE UMA TRANSMISSÃO DE VÍDEO POR ENDOSCÓPIO CIRÚRGICO
# - ENDOSCÓPIO ELETRÔNICO E SISTEMA DE ENDOSCÓPIO ELETRÔNICO
# - INVÓLUCRO PARA UMA PONTA DE UM DISPOSITIVO DE DIGITALIZAÇÃO E SISTEMA DO MESMO
# - DISPOSITIVO DE ENERGIA ADAPTÁVEL PARA DIGITALIZAÇÃO DE UMA INTRACAVIDADE HUMANA
# - APRIMORAMENTO DE VÍDEO DE ENDOSCÓPIO AUTOMÁTICO
# - SISTEMA INDICADOR
# - COMPOSIÇÃO VISCOELÁSTICA PARA FIXAR O CAMPO VISUAL DO ENDOSCÓPIO
# - DISPOSITIVO DE DIGITALIZAÇÃO SEM FIO
# - DISPOSITIVO ENDOSCÓPICO E MÉTODOS DE USO DO MESMO
# - CATETER VASCULAR E MÉTODO
# - MÉTODO E SISTEMA PARA ORIENTAR UM ESCANEAMENTO DE UMA MANDÍBULA, E, MEIO DE ARMAZENAMENTO LEGÍVEL POR COMPUTADOR NÃO TRANSITÓRIO
# - SISTEMA DE DIGITALIZAÇÃO INTRAORAL UTILIZANDO INDUÇÃO MAGNÉTICA
# - DISPOSITIVO DE SCANNER COM PONTAS DE ESCANEAMENTO SUBSTITUÍVEIS
# - INDICADOR DE LIMPEZA E MÉTODO DE USO DO MESMO
# - DISPOSITIVOS ENDOSCÓPICOS E MÉTODOS RELACIONADOS
# - ESPÉCULO DE AR
# - PRODUTO DE IMAGEM HÍBRIDA E SISTEMA ENDOSCÓPICO HÍBRIDO
# - TUBULAÇÃO COM FIBRA ÓPTICA INTEGRADA, DISPOSITIVOS MÉDICOS, E MÉTODOS DOS MESMOS
# - DISPOSITIVO PARA COLETA DE VASO
# - APARELHO DE AQUISIÇÃO DE IMAGEM DO COLO DO ÚTERO
# - DISPOSITIVO DE LIMPEZA PARA FERRAMENTA CIRÚRGICA
# - DISPOSITIVOS PARA O TRATAMENTO DE HIPERPLASIA PROSTÁTICA BENIGNA E SINTOMAS DO TRATO URINÁRIO INFERIOR RELACIONADOS
# - ANÁLISE DE TENDÊNCIAS CIRÚRGICAS POR UM SISTEMA CIRÚRGICO E FORNECIMENTO DE RECOMENDAÇÕES A USUÁRIOS
# - CONTROLE DE SISTEMA CIRÚRGICO ADAPTATIVO DE ACORDO COM CARACTERÍSTICAS DA NUVEM DE FUMAÇA CIRÚRGICA
# - VISUALIZAÇÃO ADAPTATIVA POR UM SISTEMA CIRÚRGICO
# - CONTROLE DE SISTEMA CIRÚRGICO BASEADO EM MÚLTIPLOS PARÂMETROS DETECTADOS
# - CONTROLE DE SISTEMA CIRÚRGICO ADAPTATIVO DE ACORDO COM CARACTERÍSTICAS DO PARTICULADO DE FUMAÇA CIRÚRGICA
# - SISTEMA E MÉTODO PARA DETERMINAR, AJUSTAR E GERENCIAR MARGEM DE RESSEÇÃO AO REDOR DE UM TECIDO PRETENDIDO
# - DISPOSITIVO MÉDICO, MÉTODO PARA CONTROLAR UM DISPOSITIVO, SISTEMA COMPREENDENDO UM DISPOSITIVO, E MÉTODO PARA PRODUZIR UM DISPOSITIVO
# - DISPOSITIVO DE EXAME MÉDICO
# - ADAPTADOR INTRAORAL
# - CATETER CONFIGURADO PARA SER INSERIDO EM UM DISPOSITIVO ENDOSCÓPICO, KIT DE CATETER E MÉTODO PARA MANIPULAR UM CATETER
# - SISTEMAS, MÉTODOS E APARELHO PARA FIXAÇÃO DE UM OTOSCÓPIO
# - SISTEMA DE ENDOSCÓPIO E MÉTODO PARA DETECTAR QUANDO A EXTREMIDADE FINAL DO ENDOSCÓPIO ENTRA EM CONTATO COM O TECIDO
# - CONTROLE DE EXIBIÇÃO DE SISTEMA EM CAMADAS COM BASE NA CAPACIDADE E NA OPERAÇÃO DE USUÁRIO
# - SISTEMA DE VISUALIZAÇÃO CIRÚRGICA PROGRAMÁVEL EM CAMPO
# - SISTEMA DE VISUALIZAÇÃO CIRÚRGICA COM ACESSO HIERÁRQUICO
# - SISTEMA DE VISUALIZAÇÃO CIRÚRGICA E ANÁLISE DE TENDÊNCIAS DE PARTÍCULAS
# - SISTEMA ENDOSCÓPICO ROTATIVO POSSUINDO UM TUBO DE INSERÇÃO ROTATIVO
# - SISTEMA DE GERAÇÃO DE IMAGENS E LAPAROSCÓPIO PARA GERAR IMAGENS DE UM OBJETO
# - SISTEMA PARA TRANSFERÊNCIA DE EMBRIÕES
# - VÍDEO LARINGOSCÓPIO PARA GERENCIAR A VIA AÉREA EM UM INDIVÍDUO EM NECESSIDADE DO MESMO
# - AFASTADOR CIRÚRGICO
# - SISTEMA DE SERVIÇO DE TRIAGEM DE CÂNCER CERVICAL BASEADO EM INTELIGÊNCIA ARTIFICIAL
# - PROCTOSCÓPIO
# - ALINHAMENTO DE UM DISPOSITIVO MÉDICO ENCAIXÁVEL POR CLIPE A UMA CÂMERA DE DISPOSITIVO INTELIGENTE
# - KIT DE AQUISIÇÃO
# - DISPOSITIVO DE CAPTURA PARA ENDOSCÓPIO
# - ANTECIPAÇÃO DE UTILIZAÇÃO INTERATIVA DE SOBREPOSIÇÕES DE DADOS COMUNS POR DIFERENTES USUÁRIOS
# - SISTEMA DE ENDOSCÓPIO MÉDICO
# - INSTRUMENTO MÉDICO E MÉTODO PARA A OPERAÇÃO DE UM  INSTRUMENTO MÉDICO
# - SISTEMAS E MÉTODOS IMPLEMENTADOS POR COMPUTADOR PARA ANÁLISE DA QUALIDADE DO EXAME PARA UM PROCEDIMENTO ENDOSCÓPICO
# - SCANNER INTRAORAL, SISTEMA DE VARREDURA INTRAORAL, MÉTODO DE GERAÇÃO DE MODELOS TRIDIMENSIONAIS E PRODUTO DE PROGRAMA DE COMPUTADOR
# - BAINHA MANOBRÁVEL E ACESSÓRIO DE ESCOPO AJUSTÁVEL
# - DISPOSITIVOS DE ACOPLAMENTO E SISTEMAS RELACIONADOS
# - SISTEMA DE TRATAMENTO DE CÁLCULO RENAL
# - GUIA ENDOSCÓPICA, EM PARTICULAR PARA COLONOSCÓPIOS, E SISTEMA DE ENDOSCOPIA COMPREENDENDO A REFERIDA GUIA
# - PEÇA DE MÃO MAGNÉTICA PARA UMA GUIA ENDOSCÓPICA, EM PARTICULAR PARA COLONOSCÓPIOS, E SISTEMA DE ENDOSCOPIA COMPREENDENDO A REFERIDA PEÇA DE MÃO
# - ATUADOR TERMINAL
# - DISPOSIÇÃO CONSTRUTIVA APLICADA EM EQUIPAMENTO PARA ENTUBAÇÃO ENDOTRAQUEAL
# - SIMULADOR PORTÁTIL PARA TREINAMENTO EM CIRURGIAS DE MÍNIMOS ACESSOS
# - DISPOSIÇÃO INTRODUZIDA EM LARINGOSCÓPIO DOTADO DE CÂMARA DE VÍDEO
# - DISPOSITIVO PARA INVERSÃO INSTANTÂNEA DE FLUXO DE CILINDROS DE DIÓXIDO DE CARBONO PARA INSUFLADOR LAPAROSCÓPICO
# - DISPOSIÇÃO CONSTRUTIVA EM OROSCÓPIO COM MÁQUINA FOTOGRÁFICA INTEGRADA
# - ADAPTADOR UNIVERSAL PARA BOROSCOPIA COM SMARTPHONE
# - INSTRUMENTO HISTERO-RESSECTOSCOPIO DESCARTÁVEL PARA CIRURGIAS GINECOLÓGICAS
# - DISPOSIÇÃO CONSTRUTIVA APLICADA EM DISPOSITIVO DE CONTROLE DE FIBRA ÓTICA
# - URETEROSCÓPIO SEMIRRÍGIDO DIGITAL
# - DISPOSIÇÃO INTRODUZIDA EM SOPRADOR DE AR COMPRIMIDO PARA PONTEIRA DE SCANNER INTRAORAL ODONTOLÓGICO
# - ÓTICA  PARA APLICAÇÃO EM CIRURGIA DE CRÂNIO E COLUNA
# - CAMISA ESTÉRIL PARA ENDOSCÓPIO RÍGIDO
# - DISPOSIÇÃO CONSTRUTIVA APLICADA EM CONJUNTO PORTÁTIL PARA CIRURGIA POR VÍDEO
# - INSTRUMENTO COM PONTEIRA EM FORMA DE CESTA E CANAL PARA PROBE DE UTILIZAÇÃO EM PROCEDIMENTOS ENDOSCÓPICOS, PARA APREENSÃO, FRAGMENTAÇÃO E EXTRAÇÃO DE LITÍASES NA CIRURGIA ENDOURETRAL
# - SIMULADOR PARA TREINAMENTO DE URETERORRENOLITOTRIPSIA FLEXÍVEL
# - MINICÂMERA ENDOSCÓPICA COM GRAVAÇÃO INTEGRADA
# - DISPOSIÇÃO CONSTRUTIVA INTRODUZIDA EM ENDOSCÓPIO RÍGIDO DIGITAL
# - Endoscópio Rígido Tendo Apoio Sobre o Tórax e Alça
# - DISPOSIÇÃO INTRODUZIDA EM PLATAFORMA DE TREINAMENTO MÉDICO EM VÍDEO-CIRURGIA E CIRURGIA MINIMAMENTE INVASIVA
# - CONJUNTO DE VEDAÇÃO E CONJUNTO DE TROCARTE
# - SISTEMA DE IMAGEM ÓTICA SINTÉTICA, DISPOSITIVO DE SEGURANÇA DE DOCUMENTOS, SISTEMA DE APRESENTAÇÃO DE IMAGEM E DISPOSITIVO DE SEGURANÇA OU SISTEMA DE AUTENTICAÇÃO
# - POSICIONADOR UNIVERSAL DE BARRA CLIPE COM GARRA PARA FIXAÇÃO HORIZONTAL E VERTICAL E INDICADOR DA BISSETRIZ DO ÂNGULO POSTERIOR
# - Instrumento endoscópico a ser usado com um endoscópio
# - DISPOSITIVO MULTIARTICULADO  DIRIGÍVEL
# - MEIO PROTETOR, EM PARTICULAR, PARA PROCEDIMENTOS NÃO-INVASIVOS
# - APARELHO PARA OPERAÇÕES MÉDICAS
# - INSTRUMENTO CIRÚRGICO DE CORTE E FIXAÇÃO ACIONADO A MOTOR COM CIRCUITO DE CONTROLE PARA OTIMIZAR O USO DE BATERIA
# - METODOS E APARELHOS PARA O TRATAMENTO DE TRANSTORNOS DO OUVIDO, NARIZ E GARGANTA
# - SISTEMA ROBÓTICO PARA CIRURGIA LAPAROSCÓPICA
# - APARELHO PARA DISTRIBUIR FLUIDO PARA UM ENDOSCÓPIO
# - DISPOSITIVO CIRÚRGICO
# - INSTRUMENTO ELETROCIRÚRGICO
# - APLICADOR DE SONDA
# - DISPOSITIVO COM ELEMENTO GUIADOR EM CANAL DE TRABALHO
# - INSTRUMENTO CIRÚRGICO COM UM DISPOSITIVO DETECTOR DE POSIÇÃO
# - SONDA DE TERAPIA A VÁCUO ENDOSCÓPICO
# - DISPOSITIVO PARA MONITORAMENTO ÓPTICO PARA O MONITORAMENTO DE CURVATURA AO LONGO DE UM INSTRUMENTO MÉDICO FLEXÍVEL, INSTRUMENTO MÉDICO FLEXÍVEL E MÉTODO PARA O MONITORAMENTO DE CURVATURA AO LONGO DE UM INSTRUMENTO MÉDICO FLEXÍVEL
# - ENDOSCÓPIO PARA TRATAMENTO CIRÚRGICO DE OBSTRUÇÕES NOS INTESTINOS GROSSO E DELGADO
# - SONDA PEDICULAR ENDOSCÓPICA ILUMINADA COM MONITORAMENTO DE PROXIMIDADE
# - DISPOSITIVO ACOPLADOR PARA UM ENDOSCÓPIO
# - CONSTRUÇÃO DE ARTICULAÇÃO, E, ESPÉCULO
# - ARTICULAÇÃO EM FORMA DE COBRA PARA ROBÔ CIRÚRGICO, INSTRUMENTO CIRÚRGICO E ENDOSCÓPIO
